# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install git+https://github.com/jernsting/nxt_gem.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/jernsting/nxt_gem.git
#   Cloning https://github.com/jernsting/nxt_gem.git to /tmp/pip-req-build-29ss5drd
#   Running command git clone --filter=blob:none --quiet https://github.com/jernsting/nxt_gem.git /tmp/pip-req-build-29ss5drd
#   Resolved https://github.com/jernsting/nxt_gem.git to commit 9f1ba7de35e87cb3521387cd393306a3fef5f79c
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: nxt-gem
#   Building wheel for nxt-gem (setup.py) ... done
#   Created wheel for nxt-gem: filename=nxt_gem-0.0.0-py3-none-any.whl size=2315 sha256=ab333c4e7c3e967945dd3de765303d09aa3a43a11c5fa756709aab24f9dc8239
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3j6s93z0/wheels/dd/0d/e4/913100ae467b75975766f808aa1809c1e8143a5c7b435858c9
# Successfully built nxt-gem
# Installing collected packages: nxt-gem
# Successfully installed nxt-gem-0.0.0

# %%
# !pip install theano
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting theano
#   Downloading Theano-1.0.5.tar.gz (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 23.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from theano) (1.22.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.8/dist-packages (from theano) (1.10.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from theano) (1.15.0)
# Building wheels for collected packages: theano
#   Building wheel for theano (setup.py) ... done
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668112 sha256=8c7fad3f2656bc1fb3ab18a02670aabec2ed33e7c203dbfcbf13a2cc1d455cd9
#   Stored in directory: /root/.cache/pip/wheels/84/cb/19/235b5b10d89b4621f685112f8762681570a9fa14dc1ce904d9
# Successfully built theano
# Installing collected packages: theano
# Successfully installed theano-1.0.5

# %%
import torch
x = torch.tensor((1, 2))
y = torch.tensor((3, 4))
q = 0.9
p = x - y
loss = 0
for e in p:
   loss+= max(q * e, (q - 1) * e)
2 * loss/torch.abs(torch.sum(x))

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1
# Out:
# update-alternatives: error: alternative path /usr/bin/python3.9 doesn't exist

# %%
#!pip install networkx
#!pip install scipy
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.10.1)

# %%
import matplotlib.pyplot as plt
import tqdm as tqdm
from time import time

from gem.utils import graph_util
from gem.evaluation import visualize_embedding as viz
from gem.evaluation import evaluate_graph_reconstruction as gr

from gem.embedding.hope import HOPE
from gem.embedding.lap import LaplacianEigenmaps
from gem.embedding.lle import LocallyLinearEmbedding
#from gem.embedding.sdne import SDNE
from argparse import ArgumentParser
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-f43d1a546e9f> in <module>
#       2 import tqdm as tqdm
#       3 from time import time
# ----> 4 import gem
#       5
#       6 from gem.utils import graph_util
#
# ModuleNotFoundError: No module named 'gem'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
